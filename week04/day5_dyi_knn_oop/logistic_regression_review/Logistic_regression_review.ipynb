# %% [markdown]
# <img src="http://imgur.com/1ZcRyrc.png" style="float: left; margin: 20px; height: 55px">
#
# # Logistic regression review
#
# ---

# %% [markdown]
# <h1>Lesson Guide<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Then-the-basic-workflow-generalises-in-the-following-way:" data-toc-modified-id="Then-the-basic-workflow-generalises-in-the-following-way:-1">Then the basic workflow generalises in the following way:</a></span></li><li><span><a href="#Example" data-toc-modified-id="Example-2">Example</a></span></li><li><span><a href="#Get-the-data" data-toc-modified-id="Get-the-data-3">Get the data</a></span><ul class="toc-item"><li><span><a href="#Load-the-dataset-included-in-sklearn" data-toc-modified-id="Load-the-dataset-included-in-sklearn-3.1">Load the dataset included in sklearn</a></span></li><li><span><a href="#Load-the-feature-matrix" data-toc-modified-id="Load-the-feature-matrix-3.2">Load the feature matrix</a></span></li><li><span><a href="#Load-the-target-variable" data-toc-modified-id="Load-the-target-variable-3.3">Load the target variable</a></span></li><li><span><a href="#Train-test-split" data-toc-modified-id="Train-test-split-3.4">Train-test split</a></span></li><li><span><a href="#Rescale-the-features" data-toc-modified-id="Rescale-the-features-3.5">Rescale the features</a></span></li></ul></li><li><span><a href="#Logistic-regression" data-toc-modified-id="Logistic-regression-4">Logistic regression</a></span><ul class="toc-item"><li><span><a href="#Create-an-instance-of-the-model-(here-you-could-also-use-other-classifiers)" data-toc-modified-id="Create-an-instance-of-the-model-(here-you-could-also-use-other-classifiers)-4.1">Create an instance of the model (here you could also use other classifiers)</a></span></li><li><span><a href="#Check-for-the-parameters-of-the-model-(each-model-will-come-with-its-own-particular-set-of-parameters)" data-toc-modified-id="Check-for-the-parameters-of-the-model-(each-model-will-come-with-its-own-particular-set-of-parameters)-4.2">Check for the parameters of the model (each model will come with its own particular set of parameters)</a></span></li><li><span><a href="#Set-up-a-search-grid-for-the-parameters-you-want-to-tune-in-form-of-a-dictionary-with-the-tuning-parameters-as-keys-and-lists-of-possible-values" data-toc-modified-id="Set-up-a-search-grid-for-the-parameters-you-want-to-tune-in-form-of-a-dictionary-with-the-tuning-parameters-as-keys-and-lists-of-possible-values-4.3">Set up a search grid for the parameters you want to tune in form of a dictionary with the tuning parameters as keys and lists of possible values</a></span></li><li><span><a href="#Call-GridSearchCV-with-the-model,-the-parameter-grid,-the-number-of-cross-validation-steps-and-the-scoring-of-your-choice" data-toc-modified-id="Call-GridSearchCV-with-the-model,-the-parameter-grid,-the-number-of-cross-validation-steps-and-the-scoring-of-your-choice-4.4">Call GridSearchCV with the model, the parameter grid, the number of cross validation steps and the scoring of your choice</a></span></li><li><span><a href="#Fit-the-model" data-toc-modified-id="Fit-the-model-4.5">Fit the model</a></span></li><li><span><a href="#Extract-the-best-model" data-toc-modified-id="Extract-the-best-model-4.6">Extract the best model</a></span></li><li><span><a href="#Extract-the-scores" data-toc-modified-id="Extract-the-scores-4.7">Extract the scores</a></span><ul class="toc-item"><li><span><a href="#Cross-validated-training-score-of-the-best-model" data-toc-modified-id="Cross-validated-training-score-of-the-best-model-4.7.1">Cross validated training score of the best model</a></span></li><li><span><a href="#Score-on-the-whole-training-set" data-toc-modified-id="Score-on-the-whole-training-set-4.7.2">Score on the whole training set</a></span></li><li><span><a href="#The-score-of-the-best-model-on-the-test-set" data-toc-modified-id="The-score-of-the-best-model-on-the-test-set-4.7.3">The score of the best model on the test set</a></span></li></ul></li><li><span><a href="#Extract-the-best-parameters" data-toc-modified-id="Extract-the-best-parameters-4.8">Extract the best parameters</a></span></li><li><span><a href="#Choose-the-model-with-the-best-parameters-and-predict-target-variable-values-(here-chosen-for-some-of-the-values-in-the-dataset)" data-toc-modified-id="Choose-the-model-with-the-best-parameters-and-predict-target-variable-values-(here-chosen-for-some-of-the-values-in-the-dataset)-4.9">Choose the model with the best parameters and predict target variable values (here chosen for some of the values in the dataset)</a></span></li><li><span><a href="#Further-analysis" data-toc-modified-id="Further-analysis-4.10">Further analysis</a></span><ul class="toc-item"><li><span><a href="#Get-all-results-from-the-grid-search-(they-are-returned-as-a-dictionary-that-you-can-conveniently-read-into-a-data-frame)" data-toc-modified-id="Get-all-results-from-the-grid-search-(they-are-returned-as-a-dictionary-that-you-can-conveniently-read-into-a-data-frame)-4.10.1">Get all results from the grid search (they are returned as a dictionary that you can conveniently read into a data frame)</a></span></li><li><span><a href="#The-most-interesting-result-is-the-mean-test-score-for-each-parameter-combination" data-toc-modified-id="The-most-interesting-result-is-the-mean-test-score-for-each-parameter-combination-4.10.2">The most interesting result is the mean test score for each parameter combination</a></span></li></ul></li></ul></li><li><span><a href="#Code-summary" data-toc-modified-id="Code-summary-5">Code summary</a></span></li><li><span><a href="#Use-LogisticRegressionCV-in-combination-with-gridsearch" data-toc-modified-id="Use-LogisticRegressionCV-in-combination-with-gridsearch-6">Use <code>LogisticRegressionCV</code> in combination with gridsearch</a></span></li></ul></div>

# %% [markdown]
# We have covered various models for classification and regression which allow us to fit a response variable to a set of feature variables. Usually, all models have a variety of parameters which can be tuned to find the best among all possible models. Best in that context means not only fitting the training data well, but generalising also to previously unseen test data.
#
# In the lessons you have seen how to use regularisation and grid search in combination with cross validation to find a good model according to model scores like MSE and R2 in the case of regression, and accuracy, recall or precision in the case of classification.
#
# As a reference below we will illustrate this procedure for a binary classification problem with logistic regression.
#
# The same steps can be used for other models if you replace with the appropriate tuning parameters.
#
#
# We assume you already have a data set with the features and the target you want to model (this is the output you get from doing the EDA).
#
# Then the basic workflow generalises in the following way:
# -----
#
# 1. Create an Instance of the model
#
# 1. Check for the parameters of the model (each model will come with its own particular set of parameters)
#
# 1. Set up a search grid for the parameters you want to tune in form of a dictionary with the tuning parameters as keys and lists of possible values
#
# 1. Call GridSearchCV with the model, the parameter grid, the number of cross validation steps and the scoring of your choice
#
# 1. Fit the model
#
# 1. Extract the best score
#
# 1. Extract the best parameters
#
# 1. Choose the model with the best parameters and predict target variable values (here chosen for some of the values in the dataset)

# %% [markdown]
# ## Example

# %% [markdown]
# First we load the libraries that we will need.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
 
plt.style.use('ggplot')
sns.set(font_scale=1.5)
# %config InlineBackend.figure_format = 'retina'
# %matplotlib inline

# %%
from sklearn import datasets, metrics
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LogisticRegression, LogisticRegressionCV
from sklearn.model_selection import train_test_split, cross_val_score, GridSearchCV

# %% [markdown]
# ## Get the data

# %% [markdown]
# ### Load the dataset included in sklearn
#
# - Choose breast cancer for binary classification
# - Choose iris for multiclass classification

# %%
# Choose one of the two datasets

data = datasets.load_breast_cancer()
#data = datasets.load_iris()

# %% [markdown]
# ### Load the feature matrix

# %%
X = pd.DataFrame(data.data, columns=data.feature_names)

X.head(3)
# Out:
#    mean radius  mean texture  mean perimeter  mean area  mean smoothness  \
# 0        17.99         10.38           122.8     1001.0          0.11840
# 1        20.57         17.77           132.9     1326.0          0.08474
# 2        19.69         21.25           130.0     1203.0          0.10960
#
#    mean compactness  mean concavity  mean concave points  mean symmetry  \
# 0           0.27760          0.3001              0.14710         0.2419
# 1           0.07864          0.0869              0.07017         0.1812
# 2           0.15990          0.1974              0.12790         0.2069
#
#    mean fractal dimension           ...             worst radius  \
# 0                 0.07871           ...                    25.38
# 1                 0.05667           ...                    24.99
# 2                 0.05999           ...                    23.57
#
#    worst texture  worst perimeter  worst area  worst smoothness  \
# 0          17.33            184.6      2019.0            0.1622
# 1          23.41            158.8      1956.0            0.1238
# 2          25.53            152.5      1709.0            0.1444
#
#    worst compactness  worst concavity  worst concave points  worst symmetry  \
# 0             0.6656           0.7119                0.2654          0.4601
# 1             0.1866           0.2416                0.1860          0.2750
# 2             0.4245           0.4504                0.2430          0.3613
#
#    worst fractal dimension
# 0                  0.11890
# 1                  0.08902
# 2                  0.08758
#
# [3 rows x 30 columns]

# %% [markdown]
# ### Load the target variable

# %%
y = pd.Series(data.target)
y.head(3)
# Out:
# 0    0
# 1    0
# 2    0
# dtype: int64

# %% [markdown]
# ### Train-test split

# %%
X_train, X_test, y_train, y_test = train_test_split(X,y,
                 stratify=y, test_size=0.3,random_state=1)

# %% [markdown]
# ### Rescale the features

# %%
scaler = StandardScaler()

X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

X_train = pd.DataFrame(X_train,columns=X.columns)
X_test = pd.DataFrame(X_test,columns=X.columns)

# %% [markdown]
# ## Logistic regression
#
# Now that we have the data (features and target), we will go through the steps in the workflow, so we can fit a linear regression on _**all**_ of our features.

# %% [markdown]
# ### Create an instance of the model (here you could also use other classifiers)

# %%
model = LogisticRegression()

# %% [markdown]
# ### Check for the parameters of the model (each model will come with its own particular set of parameters)

# %%
list(model.get_params().keys())
# Out:
# ['C',
#  'class_weight',
#  'dual',
#  'fit_intercept',
#  'intercept_scaling',
#  'max_iter',
#  'multi_class',
#  'n_jobs',
#  'penalty',
#  'random_state',
#  'solver',
#  'tol',
#  'verbose',
#  'warm_start']

# %% [markdown]
# **Note:** Not all of the model parameters are tuning parameters. 'C', 'penalty', 'fit_intercept' for example are tuning parameters, whereas 'n_jobs', 'verbose' or 'random_state' are not.

# %% [markdown]
# ### Set up a search grid for the parameters you want to tune in form of a dictionary with the tuning parameters as keys and lists of possible values

# %%
params = {'C':np.logspace(-5,5,15),
          'penalty':['l1','l2'],
          'fit_intercept':[True,False]}

# %% [markdown]
# ### Call GridSearchCV with the model, the parameter grid, the number of cross validation steps and the scoring of your choice
#
# Setting `return_train_score` to `True` will store more results.

# %%
gs = GridSearchCV(estimator=model,
                  param_grid=params,
                  cv=5,
                  scoring='accuracy',
                  return_train_score=True)

# %% [markdown]
# ### Fit the model

# %%
gs.fit(X_train,y_train)
# Out:
# GridSearchCV(cv=5, error_score='raise',
#        estimator=LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='ovr', n_jobs=1,
#           penalty='l2', random_state=None, solver='liblinear', tol=0.0001,
#           verbose=0, warm_start=False),
#        fit_params=None, iid=True, n_jobs=1,
#        param_grid={'C': array([1.00000e-05, 5.17947e-05, 2.68270e-04, 1.38950e-03, 7.19686e-03,
#        3.72759e-02, 1.93070e-01, 1.00000e+00, 5.17947e+00, 2.68270e+01,
#        1.38950e+02, 7.19686e+02, 3.72759e+03, 1.93070e+04, 1.00000e+05]), 'penalty': ['l1', 'l2'], 'fit_intercept': [True, False]},
#        pre_dispatch='2*n_jobs', refit=True, return_train_score=True,
#        scoring='accuracy', verbose=0)

# %% [markdown]
# ### Extract the best model

# %%
gs_best = gs.best_estimator_
gs_best
# Out:
# LogisticRegression(C=0.19306977288832497, class_weight=None, dual=False,
#           fit_intercept=False, intercept_scaling=1, max_iter=100,
#           multi_class='ovr', n_jobs=1, penalty='l2', random_state=None,
#           solver='liblinear', tol=0.0001, verbose=0, warm_start=False)

# %% [markdown]
# ### Extract the scores

# %% [markdown]
# #### Cross validated training score of the best model
#
# This score results as the best average of cross validation scores for any of the particular model settings.

# %%
print(gs.best_score_)
# Out:
# 0.9874371859296482

# %% [markdown]
# This is equivalent to:

# %%
cross_val_score(gs.best_estimator_,X_train,y_train,cv=5).mean()
# Out:
# 0.9874367088607595

# %% [markdown]
# #### Score on the whole training set
#
# This is the score resulting with the best model fit on the whole training set (without cross validation).

# %%
gs.score(X_train,y_train)
# Out:
# 0.9899497487437185

# %% [markdown]
# #### The score of the best model on the test set

# %%
gs.score(X_test,y_test)
# Out:
# 0.9707602339181286

# %% [markdown]
# ### Extract the best parameters

# %%
print(gs.best_params_)
# Out:
# {'C': 0.19306977288832497, 'fit_intercept': False, 'penalty': 'l2'}

# %% [markdown]
# ### Choose the model with the best parameters and predict target variable values (here chosen for some of the values in the dataset)

# %%
gs.predict(X_test.iloc[10:20])
# Out:
# array([0, 0, 1, 1, 1, 1, 0, 1, 0, 0])

# %% [markdown]
# ### Further analysis

# %% [markdown]
# #### Get all results from the grid search (they are returned as a dictionary that you can conveniently read into a data frame)

# %%
results = pd.DataFrame(gs.cv_results_)
results
# Out:
#     mean_fit_time  mean_score_time  mean_test_score  mean_train_score  \
# 0        0
# 13    0.0013895                True            l2
# 14    0.0013895               False            l1
# 15    0.0013895               False            l2
# 16   0.00719686                True            l1
# 17   0.00719686                True            l2
# 18   0.00719686               False            l1
# 19   0.00719686               False            l2
# 20    0.0372759                True            l1
# 21    0.0372759                True            l2
# 22    0.0372759               False            l1
# 23    0.0372759               False            l2
# 24      0.19307                True            l1
# 25      0.19307                True            l2
# 26      0.19307               False            l1
# 27      0.19307               False            l2
# 28            1                True            l1
# 29            1                True            l2
# 30            1               False            l1
# 31            1               False            l2
# 32      5.17947                True            l1
# 33      5.17947                True            l2
# 34      5.17947               False            l1
# 35      5.17947               False            l2
# 36       26.827                True            l1
# 37       26.827                True            l2
# 38       26.827               False            l1
# 39       26.827               False            l2
# 40       138.95                True            l1
# 41       138.95                True            l2
# 42       138.95               False            l1
# 43       138.95               False            l2
# 44      719.686                True            l1
# 45      719.686                True            l2
# 46      719.686               False            l1
# 47      719.686               False            l2
# 48      3727.59                True            l1
# 49      3727.59                True            l2
# 50      3727.59               False            l1
# 51      3727.59               False            l2
# 52        19307                True            l1
# 53        19307                True            l2
# 54        19307               False            l1
# 55        19307               False            l2
# 56       100000                True            l1
# 57       100000                True            l2
# 58       100000               False            l1
# 59       100000               False            l2
#
#                                                params  rank_test_score  \
# 0   {'C': 1e-05, 'fit_intercept': True, 'penalty':...               51
# 1   {'C': 1e-05, 'fit_intercept': True, 'penalty':...               49
# 2   {'C': 1e-05, 'fit_intercept': False, 'penalty'...               51
# 3   {'C': 1e-05, 'fit_intercept': False, 'penalty'...               47
# 4   {'C': 5.1794746792312125e-05, 'fit_intercept':...               51
# 5   {'C': 5.1794746792312125e-05, 'fit_intercept':...               49
# 6   {'C': 5.1794746792312125e-05, 'fit_intercept':...               51
# 7   {'C': 5.1794746792312125e-05, 'fit_intercept':...               47
# 8   {'C': 0.0002682695795279727, 'fit_intercept': ...               51
# 9   {'C': 0.0002682695795279727, 'fit_intercept': ...               43
# 10  {'C': 0.0002682695795279727, 'fit_intercept': ...               51
# 11  {'C': 0.0002682695795279727, 'fit_intercept': ...               35
# 12  {'C': 0.0013894954943731374, 'fit_intercept': ...               51
# 13  {'C': 0.0013894954943731374, 'fit_intercept': ...               35
# 14  {'C': 0.0013894954943731374, 'fit_intercept': ...               51
# 15  {'C': 0.0013894954943731374, 'fit_intercept': ...               19
# 16  {'C': 0.0071968567300115215, 'fit_intercept': ...               51
# 17  {'C': 0.0071968567300115215, 'fit_intercept': ...               15
# 18  {'C': 0.0071968567300115215, 'fit_intercept': ...               51
# 19  {'C': 0.0071968567300115215, 'fit_intercept': ...               13
# 20  {'C': 0.037275937203149416, 'fit_intercept': T...               22
# 21  {'C': 0.037275937203149416, 'fit_intercept': T...                5
# 22  {'C': 0.037275937203149416, 'fit_intercept': F...               22
# 23  {'C': 0.037275937203149416, 'fit_intercept': F...                7
# 24  {'C': 0.19306977288832497, 'fit_intercept': Tr...                7
# 25  {'C': 0.19306977288832497, 'fit_intercept': Tr...                3
# 26  {'C': 0.19306977288832497, 'fit_intercept': Fa...                5
# 27  {'C': 0.19306977288832497, 'fit_intercept': Fa...                1
# 28  {'C': 1.0, 'fit_intercept': True, 'penalty': '...                9
# 29  {'C': 1.0, 'fit_intercept': True, 'penalty': '...                3
# 30  {'C': 1.0, 'fit_intercept': False, 'penalty': ...                9
# 31  {'C': 1.0, 'fit_intercept': False, 'penalty': ...                2
# 32  {'C': 5.1794746792312125, 'fit_intercept': Tru...               15
# 33  {'C': 5.1794746792312125, 'fit_intercept': Tru...                9
# 34  {'C': 5.1794746792312125, 'fit_intercept': Fal...               13
# 35  {'C': 5.1794746792312125, 'fit_intercept': Fal...                9
# 36  {'C': 26.826957952797272, 'fit_intercept': Tru...               35
# 37  {'C': 26.826957952797272, 'fit_intercept': Tru...               15
# 38  {'C': 26.826957952797272, 'fit_intercept': Fal...               26
# 39  {'C': 26.826957952797272, 'fit_intercept': Fal...               15
# 40  {'C': 138.9495494373139, 'fit_intercept': True...               26
# 41  {'C': 138.9495494373139, 'fit_intercept': True...               19
# 42  {'C': 138.9495494373139, 'fit_intercept': Fals...               35
# 43  {'C': 138.9495494373139, 'fit_intercept': Fals...               21
# 44  {'C': 719.6856730011528, 'fit_intercept': True...               22
# 45  {'C': 719.6856730011528, 'fit_intercept': True...               26
# 46  {'C': 719.6856730011528, 'fit_intercept': Fals...               26
# 47  {'C': 719.6856730011528, 'fit_intercept': Fals...               35
# 48  {'C': 3727.593720314938, 'fit_intercept': True...               26
# 49  {'C': 3727.593720314938, 'fit_intercept': True...               26
# 50  {'C': 3727.593720314938, 'fit_intercept': Fals...               35
# 51  {'C': 3727.593720314938, 'fit_intercept': Fals...               43
# 52  {'C': 19306.977288832535, 'fit_intercept': Tru...               26
# 53  {'C': 19306.977288832535, 'fit_intercept': Tru...               26
# 54  {'C': 19306.977288832535, 'fit_intercept': Fal...               35
# 55  {'C': 19306.977288832535, 'fit_intercept': Fal...               43
# 56  {'C': 100000.0, 'fit_intercept': True, 'penalt...               22
# 57  {'C': 100000.0, 'fit_intercept': True, 'penalt...               26
# 58  {'C': 100000.0, 'fit_intercept': False, 'penal...               35
# 59  {'C': 100000.0, 'fit_intercept': False, 'penal...               43
#
#     split0_test_score       ...         split2_test_score  split2_train_score  \
# 0              0.3750       ...                    0.3750            0.371069
# 1              0.9375       ...                    0.8750            0.949686
# 2              0.3750       ...                    0.3750            0.371069
# 3              0.9500       ...                    0.8750            0.943396
# 4              0.3750       ...                    0.3750            0.371069
# 5              0.9375       ...                    0.8750            0.949686
# 6              0.3750       ...                    0.3750            0.371069
# 7              0.9500       ...                    0.8750            0.943396
# 8              0.3750       ...                    0.3750            0.371069
# 9              0.9625       ...                    0.8750            0.949686
# 10             0.3750       ...                    0.3750            0.371069
# 11             0.9750       ...                    0.8875            0.952830
# 12             0.3750       ...                    0.3750            0.371069
# 13             0.9625       ...                    0.8750            0.952830
# 14             0.3750       ...                    0.3750            0.371069
# 15             0.9875       ...                    0.8875            0.962264
# 16             0.3750       ...                    0.3750            0.371069
# 17             0.9875       ...                    0.9000            0.965409
# 18             0.3750       ...                    0.3750            0.371069
# 19             0.9875       ...                    0.9000            0.971698
# 20             0.9375       ...                    0.9250            0.949686
# 21             0.9875       ...                    0.9500            0.981132
# 22             0.9375       ...                    0.9250            0.946541
# 49            1.000000      0.000722        0.000039        0.023096
# 50            1.000000      0.012521        0.000071        0.024129
# 51            1.000000      0.000571        0.000029        0.022197
# 52            1.000000      0.009610        0.000035        0.023096
# 53            1.000000      0.000903        0.000111        0.023096
# 54            1.000000      0.012102        0.000038        0.024129
# 55            1.000000      0.000661        0.000004        0.022197
# 56            1.000000      0.008861        0.000006        0.024390
# 57            1.000000      0.000845        0.000012        0.023096
# 58            1.000000      0.012368        0.000015        0.024129
# 59            1.000000      0.000810        0.000004        0.022197
#
#     std_train_score
# 0          0.000966
# 1          0.008560
# 2          0.000966
# 3          0.006590
# 4          0.000966
# 5          0.008560
# 6          0.000966
# 7          0.005500
# 8          0.000966
# 9          0.008514
# 10         0.000966
# 11         0.007579
# 12         0.000966
# 13         0.008306
# 14         0.000966
# 15         0.006150
# 16         0.000966
# 17         0.001952
# 18         0.000966
# 19         0.004692
# 20         0.005228
# 21         0.003064
# 22         0.006674
# 23         0.001275
# 24         0.005947
# 25         0.001541
# 26         0.003058
# 27         0.002517
# 28         0.003064
# 29         0.002517
# 30         0.003430
# 31         0.001983
# 32         0.002354
# 33         0.002808
# 34         0.001540
# 35         0.002808
# 36         0.002515
# 37         0.002354
# 38         0.002515
# 39         0.001540
# 40         0.000000
# 41         0.002515
# 42         0.000000
# 43         0.002515
# 44         0.000000
# 45         0.000000
# 46         0.000000
# 47         0.000000
# 48         0.000000
# 49         0.000000
# 50         0.000000
# 51         0.000000
# 52         0.000000
# 53         0.000000
# 54         0.000000
# 55         0.000000
# 56         0.000000
# 57         0.000000
# 58         0.000000
# 59         0.000000
#
# [60 rows x 23 columns]

# %% [markdown]
# #### The most interesting result is the mean test score for each parameter combination

# %%
results[['mean_test_score'] + [col for col in results.columns if 'param_' in col]].head()
# Out:
#    mean_test_score      param_C param_fit_intercept param_penalty
# 0         0.371859        1e-05                True            l1
# 1         0.929648        1e-05                True            l2
# 2         0.371859        1e-05               False            l1
# 3         0.932161        1e-05               False            l2
# 4         0.371859  5.17947e-05                True            l1

# %%
grouped = results.groupby(['param_penalty','param_fit_intercept'])
groups = list(grouped.groups.keys())

for i in range(len(groups)):
    grouped.get_group(groups[i]).plot(
        x='param_C',y='mean_test_score',logx=True,lw=3,c='b',title='Penalty: {} , Intercept: {}'.format(groups[i][0],groups[i][1]))
plt.show()

# %% [markdown]
# ## Code summary

# %%
# prepare the data

X = pd.DataFrame(data.data, columns=data.feature_names)
y = pd.Series(data.target)

X_train, X_test, y_train, y_test = train_test_split(X,y,
                 stratify=y, test_size=0.3,random_state=1)

scaler = StandardScaler()

X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

X_train = pd.DataFrame(X_train,columns=X.columns)
X_test = pd.DataFrame(X_test,columns=X.columns)

# %%
# choose and inspect the model

model = LogisticRegression()
list(model.get_params().keys())
# Out:
# ['C',
#  'class_weight',
#  'dual',
#  'fit_intercept',
#  'intercept_scaling',
#  'max_iter',
#  'multi_class',
#  'n_jobs',
#  'penalty',
#  'random_state',
#  'solver',
#  'tol',
#  'verbose',
#  'warm_start']

# %%
# setup the grid search

params = {'C':np.logspace(-4,4,10),
          'penalty':['l1','l2'],
          'fit_intercept':[True,False]}

gs = GridSearchCV(estimator=model,
                  param_grid=params,
                  cv=5,
                  scoring='accuracy',
                  return_train_score=True)

gs.fit(X_train,y_train)

# extract the grid search results

print('Best Parameters:')
print(gs.best_params_)
print('Best estimator C:')
print(gs.best_estimator_.C)
print('Best estimator mean cross validated training score:')
print(gs.best_score_)
print('Best estimator score on the full training set:')
print(gs.score(X_train,y_train))
print('Best estimator score on the test set:')
print(gs.score(X_test,y_test))
print('Best estimator coefficients:')
print(gs.best_estimator_.coef_)
# Out:
# Best Parameters:
# {'C': 0.3593813663804626, 'fit_intercept': False, 'penalty': 'l2'}
# Best estimator C:
# 0.3593813663804626
# Best estimator mean cross validated training score:
# 0.9849246231155779
# Best estimator score on the full training set:
# 0.9899497487437185
# Best estimator score on the test set:
# 0.9707602339181286
# Best estimator coefficients:
# [[-0.39221205 -0.41110342 -0.38132106 -0.51424751 -0.01743448  0.1486134
#   -0.62566866 -0.60489042 -0.17450948  0.28648589 -0.91376365 -0.13592329
#   -0.66565792 -0.72691238  0.05437368  0.58542256  0.11788364 -0.09033901
#    0.11596495  0.33711335 -0.71225724 -0.74977667 -0.62671833 -0.80153355
#   -0.5322561  -0.10063989 -0.65521293 -0.62677982 -0.69089593 -0.28391266]]

# %% [markdown]
# > **Note:** This grid searched model will only select a single `C` even in the multiclass classification problem, i.e. the same `C` for all one-versus-rest models.

# %% [markdown]
# ## Use `LogisticRegressionCV` in combination with gridsearch

# %%
# choose and inspect the model

model = LogisticRegressionCV()
list(model.get_params().keys())
# Out:
# ['Cs',
#  'class_weight',
#  'cv',
#  'dual',
#  'fit_intercept',
#  'intercept_scaling',
#  'max_iter',
#  'multi_class',
#  'n_jobs',
#  'penalty',
#  'random_state',
#  'refit',
#  'scoring',
#  'solver',
#  'tol',
#  'verbose']

# %%
# setup the grid search

params = {'penalty':['l1','l2'],
          'Cs': [np.logspace(-4,4,10)],
          'fit_intercept':[True,False],
          'solver':['liblinear']}

gs = GridSearchCV(estimator=model,
                  param_grid=params,
                  cv=5,
                  scoring='accuracy',
                  return_train_score=True)

gs.fit(X_train,y_train)

# extract the grid search results

print('Best Parameters:')
print(gs.best_params_)
print('Best estimator C:')
print(gs.best_estimator_.C_)
print('Best estimator mean cross validated training score:')
print(gs.best_score_)
print('Best estimator score on the full training set:')
print(gs.score(X_train,y_train))
print('Best estimator score on the test set:')
print(gs.score(X_test,y_test))
print('Best estimator coefficients:')
print(gs.best_estimator_.coef_)
# Out:
# Best Parameters:
# {'Cs': array([1.00000000e-04, 7.74263683e-04, 5.99484250e-03, 4.64158883e-02,
#        3.59381366e-01, 2.78255940e+00, 2.15443469e+01, 1.66810054e+02,
#        1.29154967e+03, 1.00000000e+04]), 'fit_intercept': False, 'penalty': 'l2', 'solver': 'liblinear'}
# Best estimator C:
# [0.35938137]
# Best estimator mean cross validated training score:
# 0.9849246231155779
# Best estimator score on the full training set:
# 0.9899497487437185
# Best estimator score on the test set:
# 0.9707602339181286
# Best estimator coefficients:
# [[-0.39221205 -0.41110342 -0.38132106 -0.51424751 -0.01743448  0.1486134
#   -0.62566866 -0.60489042 -0.17450948  0.28648589 -0.91376365 -0.13592329
#   -0.66565792 -0.72691238  0.05437368  0.58542256  0.11788364 -0.09033901
#    0.11596495  0.33711335 -0.71225724 -0.74977667 -0.62671833 -0.80153355
#   -0.5322561  -0.10063989 -0.65521293 -0.62677982 -0.69089593 -0.28391266]]

# %% [markdown]
# > **Note:** This grid searched model will select an optimal `C` for each one-versus-rest model.
