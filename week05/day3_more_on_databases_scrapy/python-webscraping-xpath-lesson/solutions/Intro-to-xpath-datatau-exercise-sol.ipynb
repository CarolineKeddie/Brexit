# %% [markdown]
# <img src="http://imgur.com/1ZcRyrc.png" style="float: left; margin: 20px; height: 55px">
#
# # Introduction to XPath
#
#
# ---
#
# ### Learning Objectives
# - Understand scraping basics
# - Understand the structure and content of HTML
# - Utilize XPath to extract information from HTML

# %% [markdown]
# ### STUDENT PRE-WORK
# *Before this lesson, you should already be able to:*
# - Understand basic HTML concepts
# - Worked with Beautiful Soup

# %% [markdown]
# ### LESSON GUIDE
#
# - [Introduction](#introduction)
# - [HTML](#html)
#     - [Elements](#elements)
#     - [Attributes](#attributes)
# - [What is XPath?](#xpath)
#     - [Absolute References](#xpath_absolute)
#     - [Relative References](#xpath_relative)
#     - ["Wheres Waldo?" Exercise](#waldo_exercise)
# - [1 vs N Selectors](#1_v_n)
# - [Demo Code](#demo)
#     - [Scrape Data Tau](#scrape_tau)
# - [Independent Practice](#ind_practice)
#
# ---

# %% [markdown]
# <a id='introduction'></a>
# ## Introduction: Scraping Overview (10 mins)
#
# Web scraping is a technique of extracting information from websites. It focuses on transformation of unstructured data on the web, into structured data that can be stored and analyzed.
#
# There are a variety of ways to "scrape" what we want from the web:
#
# - 3rd Party Services (import.io)
# - Write our own Python apps that pull HTML documents and parse them.
#   - Mechanize
#   - Scrapy
#   - Requests
#   - libxml / XPath
#   - Beautiful Soup
#   - Regular expressions

# %% [markdown]
# ## Discussion: What do you think would be the most challenging aspect of scraping information?
#
#
# _ie: If you were asked to scrape craigslist property listings and put them in a DataFrame(), what would hold you up?_

# %% [markdown]
# <a id='html'></a>
# ## HTML Review
#
# In the HTML DOM (Document Object Model), everything is a node:
#  * The document itself is a document node.
#  * All HTML elements are element nodes.
#  * All HTML attributes are attribute nodes.
#  * Text inside HTML elements are text nodes.
#  * Comments are comment nodes.

# %% [markdown]
# ## Html in iPython
#
# You can write html style text in a Jupyter Notebook the same way you can markdown style text.
# ```
# <p>I am a paragraph.</p>
# <strong>I am bold.</strong>
# ```
# <p>I am a paragraph.</p>
# <strong>I am bold.</strong>

# %% [markdown]
# <a id='elements'></a>
# ## Elements
# Elements begin and end with **open and close "tags"**, which are defined by namespaced, encapsulated strings.
#
# ```html
# <title>I am a title.</title>
# <p>I am a paragraph.</p>
# <strong>I am bold.</strong>
# ```
#
# _note: the tags **title, p, and strong** are represented here._

# %% [markdown]
# ## Element Parent / Child Relationships
#
# <img src="http://www.htmlgoodies.com/img/2007/06/flowChart2.gif" width="250">
#
# **Elements begin and end in the same namespace like so:**  `<p></p>`
#
# **Elements can have parents and children:**
#
# ```html
# <body>
#     <div>I am inside the parent element
#         <div>I am inside a child element</div>
#         <div>I am inside another child element</div>
#         <div>I am inside yet another child element</div>
#     </div>
# </body>
# ```

# %% [markdown]
# <a id='attributes'></a>
#
# ## Element Attributes
#
# Elements can also have attributes!  Attributes are defined inside **element tags** and can contain data that may be useful to scrape.
#
# ```html
# <a href="http://lmgtfy.com/?q=html+element+attributes" title="A title" id="web-link" name="hal">A Simple Link</a>
# ```
#
# The **element attributes** of this `<a>` tag element are:
# - id
# - href
# - title
# - name
#
# This `<a>` tag example will render in your browser like this:
# > <a href="https://www.youtube.com/watch?v=dQw4w9WgXcQ">A Simple Link</a>

# %% [markdown]
# ## Can you identify an attribute, an element, a text item, and a child element?
#
# ```HTML
# <html>
#    <title id="main-title">All this scraping is making me itch!</title>
#    <body>
#        <h1>Welcome to my Homepage</h1>
#        <p id="welcome-paragraph" class="strong-paragraph">
#            <span>Hello friends, let me tell you about this cool hair product..</span>
#            <ul>
#               <li>It's cool</li>
#               <li>It's fresh</li>
#               <li>It can tell the future</li>
#               <li>Always be closing</li>
#            </ul>
#        </p>
#    </body>
# ```
#
# **Bonus: What's missing?**

# %% [markdown]
# <a id='xpath'></a>
#
# ## Enter XPath
#
# XPath uses path expressions to select nodes or node-sets in an HTML/XML document. These path expressions look very much like the expressions you see when you work with a traditional computer file system.

# %% [markdown]
# <a id='xpath'></a>
#
# ## What is XPath?
#
# ---
#
#
# Understanding how to identify elements and attributes within HTML documents gives us the capability to write simple expressions that create structured data.  We can think os XPath like a query language for querying HTML.
#
# To make this process easier to deal with, we will be using XPath helper, which is a Chrome addon.  It's not necessary, but highly recommended to help build XPath expressions.
#
# [XPath Helper](https://chrome.google.com/webstore/detail/xpath-helper/hgimnogjllphhhkhlmebbmlgjoejdpjl?hl=en)
#
# XPath expressions can select elements, element attributes, and element text.  These selections can be either to a single item, or multiple items.  Generally, if you're not specific enough, you will end up selecting multiple elements.
#
#
# <a id='multiple-selections'></a>
# ### Multiple selections
#
# ***Multiple selections*** are useful for capturing search results, or any repeating element.  For instance, the _titles_ of an apartment listing search results from Craigslist:
#
#
# **URL - 1**
#
# [https://www.gumtree.com/london](https://www.gumtree.com/london)
#
# **Example HTML Markup**
# ```
# ...
# <div class="listing-card-content">
#     <h2 class="listing-card-title xh-highlight">Iveco daily 17 seats minibus 43000 on clock </h2>
#     <div class="listing-card-description-cont">
#     <span class="listing-card-location">Surrey Quays</span>
#     <span class="listing-card-category"> Vans </span>
#     </div>
#     <span class="listing-card-price">£3,950</span>
# </div>
#
# ...
# ```
#
# **XPath - Multiple Titles** _copy this into the XPath Helper Query box_
# ```
# //h2[@class='listing-card-title']
# ```
# **Returns (Ad Titles)**
#
#
# **URL - 2**
#
# [http://sfbay.craigslist.org/search/sfc/apa](http://sfbay.craigslist.org/search/sfc/apa)
#
#
# **Example HTML Markup**
# ```
# ...
# <span class="pl">
#     <time datetime="2016-01-12 23:27" title="Tue 12 Jan 11:27:35 PM">Jan 12</time>
#     <a href="/sfc/apa/5400584579.html" data-id="5400584579" class="hdrlnk">Welcome home to a sweetly renovated four bedroom one and a half bath</a>
# </span>
# ...
# ```
#
# **XPath - Multiple Titles** _copy this into the XPath Helper Query box_
# ```
# //a[@class='result-title hdrlnk']
# ```
#
# **Returns (Ad Titles)**

# %% [markdown]
# <a id='singlular-selections'></a>
#
# ### Singular selections
#
# ***Singular selections*** are necessary when you want to grab specific, unique text within elements.  Here's an example of a details page on Craigslist:
#
#
# **URL**
#
# [https://www.gumtree.com/p/desktop-workstation-pcs/apple-mac-pro-mid-2010-/1274947267](https://www.gumtree.com/p/desktop-workstation-pcs/apple-mac-pro-mid-2010-/1274947267)
#
# **HTML Markup**
#
# ```
# <div class="grid-col-12 grid-col-l-6">
# <dl class="dl-attribute-list attribute-list1">
# <dt class="">Posted</dt>
# <dd class="xh-highlight">1 day ago</dd>
# </dl> </div>
# ```
#
# **XPath - Single Item**
#
# ```
# //dl[@class='dl-attribute-list attribute-list1'][1]/dd
# ```
# **Returns (Time of posting or age of Post)**
# ```
# 1 day ago
# ```

# %% [markdown]
# ###### XPath Features
#
# XPath includes over 100 built-in functions to help us select and manipulate HTML (or XML) documents. XPath has functions for:
#
# - string values
# - numeric values
# - date and time comparison
# - sequence manipulation
# - Boolean values
# - and more!
#
# https://devhints.io/xpath

# %% [markdown]
# ## Basic XPath Expressions
#
# XPath comes with a wide array of features but the basics of selecting data are the most common problems that XPath can help you solve.
#
# The most common task you'll use **XPath** for is selecting data from HTML documents.  There are two ways you can **select elements** within HTML using **XPath**:
#
# - Absolute reference
# - Relative reference

# %% [markdown]
# <a id='xpath_absolute'></a>
# # XPath:  Absolute References
#
# _For our XPath demonstration, we will use Scrapy, which is using libxml under the hood.  Libxml provides the basic functionality for XPath expressions._

# %%
# Before using scrapy, you need to install it. Run the following in the terminal:
# pip install scrapy
# pip install --upgrade zope2 (you need to run the command as admin (sudo...))

# %%
from scrapy.selector import Selector
from scrapy.http import HtmlResponse

# %%
HTML = """
<html>
    <body>
        <span id="only-span">good</span>
    </body>
</html>
"""
# The same thing but "absolute" reference
Selector(text=HTML).xpath('/html/body/span/text()').extract()

# %% [markdown]
# <a id='xpath_relative'></a>
# ## Relative Reference
#
# Relative references in XPath match the "ends" of structures.  Since there is only a single "span" element, `//span/text()` matches **one element**.

# %%
Selector(text=HTML).xpath('//span/text()').extract()

# %% [markdown]
# ## Selecting Attributes
#
# Attributes **within a tag**, such as `id="only-span"` within our span attribute.  We can get the attribute by using `@` symbol **after** the **element reference**.

# %%
Selector(text=HTML).xpath('//span/@id').extract()

# %% [markdown]
# <a id='waldo_exercise'></a>
# ## (~10 mins) Where's Waldo - "XPath Edition"
#
# In this example, we will find Waldo together.  Find Waldo as:
#
# - Element
# - Attribute
# - Text element

# %%
HTML = """
<html>
    <body>
        
        <ul id="waldo">
            <li class="waldo">
                <span> yo Im not here</span>
            </li>
            <li class="waldo">Height:  ???</li>
            <li class="waldo">Weight:  ???</li>
            <li class="waldo">Last Location:  ???</li>
            <li class="nerds">
                <div class="alpha">Bill gates</div>
                <div class="alpha">Zuckerberg</div>
                <div class="beta">Theil</div>
                <div class="animal">parker</div>
            </li>
        </ul>
        
        <ul id="tim">
            <li class="tdawg">
                <span>yo im here</span>
            </li>
        </ul>
        <li>stuff</li>
        <li>stuff2</li>
        
        <div id="cooldiv">
            <span class="dsi-rocks">
               YO!
            </span>
        </div>
        
        
        <waldo>Waldo</waldo>
    </body>
</html>
"""

# %%
Selector(text=HTML).xpath('//waldo/text()').extract()
# Out:
# ['Waldo']

# %%
Selector(text=HTML).xpath('//ul[@id="waldo"]/li[1]/@class').extract()
# Out:
# ['waldo']

# %%
Selector(text=HTML).xpath('//*[@*="waldo"]').extract()
# Out:
# ['<ul id="waldo">\n            <li class="waldo">\n                <span> yo Im not here</span>\n            </li>\n            <li class="waldo">Height:  ???</li>\n            <li class="waldo">Weight:  ???</li>\n            <li class="waldo">Last Location:  ???</li>\n            <li class="nerds">\n                <div class="alpha">Bill gates</div>\n                <div class="alpha">Zuckerberg</div>\n                <div class="beta">Theil</div>\n                <div class="animal">parker</div>\n            </li>\n        </ul>',
#  '<li class="waldo">\n                <span> yo Im not here</span>\n            </li>',
#  '<li class="waldo">Height:  ???</li>',
#  '<li class="waldo">Weight:  ???</li>',
#  '<li class="waldo">Last Location:  ???</li>']

# %%
Selector(text=HTML).xpath("//*[text()='Waldo']").extract()
# Out:
# ['<waldo>Waldo</waldo>']

# %% [markdown]
# ## Solution:

# %%
# text contents of the element waldo
# Selector(text=HTML).xpath('/html/body/waldo/text()').extract()

# # Contents of all class attributes named waldo
# Selector(text=HTML).xpath('//*[@class="waldo"]').extract()
# # Contents of all attributes named waldo
# Selector(text=HTML).xpath('//*[@*="waldo"]').extract()

# # gets everything around the text element waldo
# Selector(text=HTML).xpath("//*[text()='Waldo']").extract()

# %% [markdown]
# ## 1 vs N Selections
#
# When selecting elements via relative reference, it's possible that you will select multiple items.  It's still possible to select single items, if you're specfic enough.
#
# **Singular Reference**
# - **Index** starts at **1**
# - Selections by offset
# - Selections by "first" or "last"
# - Selections by **unique attribute value**

# %%
HTML = """
<html>
    <body>
    
        <!-- Search Results -->
        <div class="search-result">
           <a href="https://www.youtube.com/watch?v=751hUX_q0Do" title="Rappin with Gas">Rapping with gas</a>
           <span class="link-details">This is a great video about gas.</span>
        </div>
        <div class="search-result">
           <a href="https://www.youtube.com/watch?v=97byWqi-zsI" title="Casio Rapmap">The Rapmaster</a>
           <span class="link-details">My first synth ever.</span>
        </div>
        <div class="search-result">
           <a href="https://www.youtube.com/watch?v=TSwqnR327fk" title="Cinco Products">Cinco Midi Organizer</a>
           <span class="link-details">Midi files at the speed of light.</span>
        </div>
        <div class="search-result">
           <a href="https://www.youtube.com/watch?v=8TCxE0bWQeQ" title="Baddest Gates">BBG Baddest Moments</a>
           <span class="link-details">It's tough to be a gangster.</span>
        </div>
        
        <!-- Page stats -->
        <div class="page-stats-container">
            <li class="item" id="pageviews">1,333,443</li>
            <li class="item" id="somethingelse">bla</li>
            <li class="item" id="last-viewed">01-22-2016</li>
            <li class="item" id="views-per-hour">1,532</li>
            <li class="item" id="kiefer-views-per-hour">5,233.42</li>
        </div>
        
    </body>
</html>
"""

# %% [markdown]
# #### Selecting the first element in a series of elements

# %%
spans = Selector(text=HTML).xpath('//span').extract()
spans[2]

# %% [markdown]
# #### Selecting the last element in a series of elements

# %%
spans = Selector(text=HTML).xpath('//span').extract()
spans[-1]

# %% [markdown]
# #### Selecting all elements matching a selection

# %%
Selector(text=HTML).xpath('//span').extract()

# %% [markdown]
# #### Selecting elements matching an _attribute_
#
# This will be one of the most common ways you will select items.  HTML DOM elements will be more differentiated based on their "class" and "id" variables.  Mainly, these types of attributes are used by web developers to refer to specfic elements or a broad set of elements to apply visual characteristics using CSS.
#
# ```HTML
# //element[@attribute="value"]
# ```
#
# **Generally**
#
# - "class" attributes within elements usually refer to multiple items
# - "id" attributes are supposed to be unique, but not always
#
# _CSS stands for cascading style sheets.  These are used to abstract the definition of visual elements on a micro and macro scale for the web.  They are also our best friend as data miners.  They give us strong hints and cues as to how a web document is structured._

# %% [markdown]
# <a id='demo'></a>
#
# ## Let's Code:
#
#  - How can we get a series of only text items for the page statistics section of our page?
#  - We want to know only how many times Kiefer views my Youtube videos page per hour?

# %%
# A:

# %% [markdown]
# <a id='scrape_tau'></a>
#
# ## Let's Scrape Data Tau Headlines
#
# DataTau is a great site for data science news. Let's take their headlines using Python **requests**, and practice selecting various elements.
#
# Using <a href="https://chrome.google.com/webstore/detail/xpath-helper/hgimnogjllphhhkhlmebbmlgjoejdpjl?hl=en">XPath helper Chrome plugin</a> _(cmd-shift-x)_ and the Chrome "inspect" feature, let's explore the structure of the page.
#
# _Here's a <a href="https://www.youtube.com/watch?v=i2Li1vnv09U">concise video</a> that demonstrates the basic inspect feature within Chrome._

# %%
# Please only run this frame once to avoid hitting the site too hard all at once
import requests

response = requests.get("http://www.datatau.com")
HTML = response.text  
HTML[0:150]           # view the first 150 characters of the HTML index document for DataTau
# Out:
# '<!DOCTYPE html>\n<!--[if lt IE 7]> <html class="no-js ie6 oldie" lang="en-US"> <![endif]-->\n<!--[if IE 7]>    <html class="no-js ie7 oldie" lang="en-US'

# %% [markdown]
# #### Selecting Only The Headlines
#
# We will use the XPath helper tool to inspect the markup that comprises the **title** to find any pattern.  Since there are more than one **titles**, we expect to find a series of elements representing the **title** data that we are interested in.
#
# ![](https://snag.gy/m4K3UE.jpg)
#
# In this example, we are referencing the the **1st center**, **3rd table row (`tr[3]`)**, within the 2nd **td having a class of "title" (`td[@class="title"][2]`)**, and the anchor tag within a **(`a/text()`)**.

# %%
import pandas as pd

titles = Selector(text=HTML).xpath('//td[@class="title"]/a/text()').extract()
titles[:5] # the first 5 titles

# %% [markdown]
# ## How do we get the urls from the titles?

# %%
urls = Selector(text=HTML).xpath('//td[@class="title"]/a/@href').extract()
urls[:5]
# titles[0:5] # the first 5 titles

# %% [markdown]
# #### How can we get the site domain, after the title within the parentheses (ie: stitchfix.com)?

# %%
# A:
# domains = Selector(text=HTML).xpath("//span[@class='comhead']/text()").extract()
domains = Selector(text=HTML).xpath("//span[@class='comhead']/text()").re('\((.*)\)')
domains[0:5]

# %% [markdown]
# #### How about the points?

# %%
# A:
points = Selector(text=HTML).xpath('//td[@class="subtext"]/span/text()').extract()
points[0:5]

# %% [markdown]
# #### How about the "more Link?"
# Hint:  You can use `element[text()='exact text']` to find text element matching specific text.

# %%
# A :
next_link = Selector(text=HTML).xpath('//a[text()="More"]/@href').extract()
next_link

# %% [markdown]
# ## Independent Practice / Lab
#
# For the next 30 minutes try to grab the following:
#
# - Story titles
# - Story URL (href)
# - Domain
# - Points
#
# Stretch:
# - Author
# - Comment count
#
# Then put into a DataFrame.
#
# - Do basic analysis of domains and point distributions
#
# ** Bonus **
#
# Automatically find the next "more link" and mine the next page(s) until none exist.  Logically, you can each page with this pseudo code:
#
# 1. Does the next link exist (a tag with text == "More")
# 1. Fetch URL, prepended with domain (datatau.com/(extracted link here))
# 1. Parse the page with `Selector(text=HTML).xpath('').extract()` to find the elements
# 1. Add to dataframe
#
# _Note:  You might want to set a limit something like 2-3 total requests per attempt to avoid unecessary transfer_

# %%
url="http://www.datatau.com"

response = requests.get(url)

links = Selector(text=response.text).xpath(
    "//td[@class='title']/a/@href").extract()
titles = Selector(text=response.text).xpath(
    "//td[@class='title']/a/text()").extract()
# points = Selector(text=response.text).xpath(
#     "//td[@class='subtext']/span/text()").extract()
domains = Selector(text=response.text).xpath(
    "//td[@class='title']/span/text()").extract()
authors = Selector(text=response.text).xpath(
    "//td[@class='subtext']/a[contains(@href, 'user')]/text()").extract()
comments = Selector(text=response.text).xpath(
    "//td[@class='subtext']/a[contains(@href, 'item')]/text()").extract()

# %% [markdown]
# ## Create a df with the data (be carefull of the missing values):

# %%
url="https://news.ycombinator.com/news"

response = requests.get(url)
l = []
ti_ = Selector(text=response.text).xpath("//tr[@class='athing']")
co_ = Selector(text=response.text).xpath("//tr/td[@class='subtext']")
for elt1, elt2 in zip(ti_,co_):
    d={}
    d['link'] = elt1.xpath("td[@class='title']/a/@href").extract()[0]
    d['title'] = elt1.xpath("td[@class='title']/a/text()").extract()[0]
    d['point'] = elt2.xpath("span[@class='score']/text()").extract()
    l.append(d)

# %%
df = pd.DataFrame(l)
df.head()
# Out:
#                                                 link         point  \
# 0  https://hacks.mozilla.org/2018/04/sneak-peek-a...  [200 points]
# 1  https://www.ft.com/content/30b5a944-3b57-11e8-...   [71 points]
# 2                   https://bvckup2.com/wip/10042018  [112 points]
# 3                  https://github.com/uber/prototool   [90 points]
# 4  https://engineering.riotgames.com/news/taxonom...   [76 points]
#
#                                                title
# 0                   Sneak Peek at WebAssembly Studio
# 1     Cancer breakthrough leads China’s biotech boom
# 2  Show HN: Visualizing disk IO activity using lo...
# 3  Prototool – A Swiss Army Knife for Protocol Bu...
# 4                       A Taxonomy of Technical Debt

# %% [markdown]
# ## Altogther into a function calling itself recurcively:

# %%
import requests
import numpy as np


def parse_url(url="https://news.ycombinator.com/news", data=False, max_page=10):

    response = requests.get(url)
    scraped = []
    ti_ = Selector(text=response.text).xpath("//tr[@class='athing']")
    co_ = Selector(text=response.text).xpath("//tr/td[@class='subtext']")
    for elt1, elt2 in zip(ti_,co_):
        d={}
        d['link'] = elt1.xpath("td[@class='title']/a/@href").extract()[0]
        d['title'] = elt1.xpath("td[@class='title']/a/text()").extract()[0]
        d['point'] = elt2.xpath("span[@class='score']/text()").extract()
        scraped.append(d)

    df = pd.DataFrame(scraped)
    
    # If there's data append it, if not, it's the first iteration, no need.
    if type(data) != bool:
        data = df.append(data)
    else:
        data = df

    # Find more link
    more_anchor = Selector(text=response.text).xpath(
        "//a[text() = 'More']/@href").extract()
    
    # Add them recurcively 
    if (len(more_anchor) > 0) and (str(max_page) not in url):
        more_url = "https://news.ycombinator.com/%s" % more_anchor[0]
        print("Fetching %s..." % more_url)
        return parse_url(more_url, data=data)
    else:
        return data.reset_index()


df = parse_url("https://news.ycombinator.com/", max_page=10)
df
# Out:
# Fetching https://news.ycombinator.com/news?p=2...
# Fetching https://news.ycombinator.com/news?p=3...
# Fetching https://news.ycombinator.com/news?p=4...
# Fetching https://news.ycombinator.com/news?p=5...
# Fetching https://news.ycombinator.com/news?p=6...
# Fetching https://news.ycombinator.com/news?p=7...
# Fetching https://news.ycombinator.com/news?p=8...
# Fetching https://news.ycombinator.com/news?p=9...
# Fetching https://news.ycombinator.com/news?p=10...
#      index                                               link         point  \
# 0        0                                   item?id=16791647   [15 points]
# 1        1                                   item?id=16793673   [10 points]
# 2        2                                   item?id=16797181    [9 points]
# 3        3  https://www.theguardian.com/technology/2018/fe...    [9 points]
# 4        4  https://energycommerce.house.gov/hearings/face...    [6 points]
# 5        5  https://www.vox.com/2016/3/29/11320386/turbota...   [20 points]
# 6        6  https://thenextweb.com/facebook/2018/04/10/fac...    [8 points]
# 7        7  https://medium.com/acing-ai/rational-ai-demyst...    [4 points]
# 8        8  https://www.cnet.com/news/nasa-4k-moon-video-t...   [21 points]
# 9        9                                   item?id=16795500    [8 points]
# 10      10                                   item?id=16795352    [8 points]
# 11      11  https://code.likeagirl.io/your-business-idea-i...   [10 points]
# 12      12  https://www.theguardian.com/us-news/2018/apr/1...  [135 points]
# 13      13  https://electrek.co/2018/04/11/elon-musk-insid...   [39 points]
# 14      14  https://www.wired.com/2016/11/block-ultrasonic...    [4 points]
# 15      15  https://www.technologyreview.com/s/610801/face...    [8 points]
# 16      16  https://fivethirtyeight.com/features/how-russi...    [4 points]
# 17      17  https://work.qz.com/1242801/gms-dress-code-is-...    [7 points]
# 18      18  https://medium.com/flutter-io/https-medium-com...    [9 points]
# 19      19  https://thenextweb.com/syndication/2018/04/05/...    [8 points]
# 20      20  https://www.washingtonpost.com/opinions/im-sui...    [4 points]
# 21      21  http://www.iamondemand.com/blog/10-things-lear...   [10 points]
# 22      22                                   item?id=16796914    [7 points]
# 23      23  https://www.cnet.com/news/steve-wozniak-quits-...    [9 points]
# 24      24                                   item?id=16796654    [6 points]
# 25      25  https://developer.atlassian.com/blog/2016/02/b...    [5 points]
# 26      26  https://www.theage.com.au/politics/federal/can...    [7 points]
# 27      27        https://www.youtube.com/watch?v=d3rS7I6Xyz8    [4 points]
# 28      28  https://aws.amazon.com/about-aws/whats-new/201...    [9 points]
# 29      29  http://blog.leapmotion.com/our-journey-to-the-...    [6 points]
# ..     ...                                                ...           ...
# 270      0  https://www.ft.com/content/30b5a944-3b57-11e8-...   [75 points]
# 271      1  https://hacks.mozilla.org/2018/04/sneak-peek-a...  [205 points]
# 272      2                   https://bvckup2.com/wip/10042018  [113 points]
# 273      3                  https://github.com/uber/prototool   [92 points]
# 274      4  https://engineering.riotgames.com/news/taxonom...   [79 points]
# 275      5  https://qz.com/1250062/uber-is-launching-uber-...   [44 points]
# 276      6  https://www.nytimes.com/2018/04/11/well/move/w...   [22 points]
# 277      7                          https://www.guilded.gg/v2   [25 points]
# 278      8  https://www.wired.com/story/this-radio-hacker-...   [21 points]
# 279      9  https://github.com/Lackoftactics/facebook_data...   [17 points]
# 280     10  https://www.theatlantic.com/science/archive/20...   [58 points]
# 281     11  https://techcrunch.com/2018/04/11/facebook-sha...   [50 points]
# 282     12  https://www.washingtonpost.com/graphics/2018/e...   [14 points]
# 283     13  https://hatsunearu.github.io/dsp/audio/electro...   [43 points]
# 284     14  https://jobs.lever.co/smarking/2350c446-7d6a-4...            []
# 285     15  http://bair.berkeley.edu/blog/2018/04/10/virtu...   [19 points]
# 286     16  https://www.imperialviolet.org/2018/04/11/pqco...   [33 points]
# 287     17  https://www.thestranger.com/features/2018/03/2...   [48 points]
# 288     18  https://creativecommons.org/2018/03/29/head-co...  [228 points]
# 289     19  https://www.bloomberg.com/news/articles/2018-0...    [3 points]
# 290     20  https://arstechnica.com/cars/2018/04/highly-ac...    [4 points]
# 291     21  https://www.gdprhq.io/post/the-new-european-ge...   [77 points]
# 292     22  https://modeldepot.github.io/tfjs-yolo-tiny-demo/    [9 points]
# 293     23  https://www.theguardian.com/lifeandstyle/2018/...   [12 points]
# 294     24  http://www.jaruzel.com/blog/Visually-Mapping-G...   [50 points]
# 295     25            https://www.geomaticventures.com/uk-map   [11 points]
# 296     26  https://techcrunch.com/2018/04/11/google-is-ab...   [74 points]
# 297     27                   https://snr.stanford.edu/salsify   [33 points]
# 298     28  https://www.facebook.com/business/m/one-sheete...   [10 points]
# 299     29  http://www.bbc.co.uk/news/science-environment-...    [5 points]
#
#                                                  title
# 0    Ask HN: Suggest features that you would love t...
# 1    Ask HN: What are you working on and why is it ...
# 2    50 years ago, a story describing modern mobile...
# 3    How an ex-YouTube insider investigated its sec...
# 4            Mark Zuckerberg's Hearing at the Congress
# 5                Why I'm boycotting TurboTax this year
# 6    Facebook could theoretically owe the FTC $7.1 ...
# 7    Rational AI: Demystifying Machine Intelligence...
# 8    Dazzling NASA 4K moon video crackles with craters
# 9         Ask HN: What do you think of the new Reddit?
# 10   Ask HN: Suggest steps that can help to stop th...
# 11             Your business idea is not unique. Sorry
# 12   Sex workers fear violence as US cracks down on...
# 13   Elon Musk gives first glimpse inside Tesla Mod...
# 14   How to block ultrasonic signals you didn't kno...
# 15   Facebook may stop the data leaks, but it’s too...
# 16   The Moscow Midterms: How Russia could steal ou...
# 17             GM's [new] dress code is only two words
# 18                           Announcing Flutter beta 2
# 19   Here is why nobody has succeeded at running Io...
# 20   Why I’m suing for my right to flip off the pre...
# 21   Things I Learned Shipping an Ancient Data Cent...
# 22   Ask HN: Resources for a doctor to learn AI and...
# 23   Steve Wozniak quits Facebook amid data concern...
# 24   Ask HN: Late career changer looking for resume...
# 25                 The best way to store your dotfiles
# 26   Australia needs to get very serious, very quic...
# 27                    Why Facebook isn't free? (Video)
# 28   Amazon S3 Select Is Generally Available (April...
# 29          Leap Motion: Our Journey to the North Star
# ..                                                 ...
# 270     Cancer breakthrough leads China’s biotech boom
# 271                   Sneak Peek at WebAssembly Studio
# 272  Show HN: Visualizing disk IO activity using lo...
# 273  Prototool – A Swiss Army Knife for Protocol Bu...
# 274                       A Taxonomy of Technical Debt
# 275  Uber is launching Uber Rent, a rental car serv...
# 276  New mouse study on how exercise alone does not...
# 277  Show HN: Guilded – build and organize online g...
# 278  Radio Hacker Can Hijack Emergency Sirens to Pl...
# 279                    Show HN: Facebook data analyzer
# 280                      The Myth of 'Learning Styles'
# 281  Zuckerberg denies knowledge of Facebook shadow...
# 282  Why Can't Hollywood Make a Good Video Game Movie?
# 283                            The Missing Fundamental
# 284  Smarking (YC W15) Is Hiring Head of Engineerin...
# 285                         Towards a Virtual Stuntman
# 286               Post-quantum confidentiality for TLS
# 287  All I Wanted Was to Work in Tech – Be Careful ...
# 288  EU copyright proposal could undermine the use ...
# 289  U.S. Agencies Agree to Slash Approval Times fo...
# 290  Live Roads promises 1.5m-accuracy with standar...
# 291                 GDPR and automated email marketing
# 292  Show HN: Using deep learning to detect objects...
# 293  How slime-crazed kids made gunk a booming busi...
# 294                       Visually Mapping Gopherspace
# 295            United Kingdom Relative Deformation Map
# 296     Google is about to launch a Gmail Web Redesign
# 297  Salsify – A New Architecture for Real-time Int...
# 298                     Facebook Updated Product Terms
# 299         Iron Age study targets British DNA mystery
#
# [300 rows x 4 columns]
